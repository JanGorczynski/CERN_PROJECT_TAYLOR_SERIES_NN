# %%
from Data_Processing.processing import get_n_data_samples, cut_to_start, scale_data, get_time_domain
import matplotlib.pyplot as plt

# %%
t = get_time_domain()

# %%
N = 13

# %%
y = get_n_data_samples(N)
scale_data(y)

# %%
x = [
    [1.39,0,0,0.25,0.26,0.6,1,0.1],
    [1.39,0,0,0.25,0.26,0.6,1,0.01],
    [1.39,0,0,0.1,0.26,0.6,1,0.1],
    [1.39,0,0,0.1,0.26,0.6,0,0.1],
    [1.39,0,0,0.25,0.26,0.6,0,0.1],
    [1.39,0,0,0.25,0.26,0.3,1,0.1],
    [1.29,0,0,0.25,0.26,0.3,1,0.1],
    [1.49,0,0,0.25,0.26,0.3,1,0.1],
    [1.39,0,0.02,0.25,0.26,0.6,1,0.1],
    [1.39,0.02,0,0.25,0.26,0.6,1,0.1],
    [1.39,0,0,0.25,0.26,0.6,1,0.05],
    [1.39,0.02,0.02,0.25,0.26,0.6,1,0.1],
    [1.39,0.1,0,0.25,0.26,0.6,1,0.1],
]

# %%
for i in range(N):
    plt.plot(get_time_domain(), y[i])
    plt.title(f'P0{i+1}A')
    plt.show()
